# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

api_key = os.getenv("NVIDIA_API_KEY")

system_message = "On va te donner un message d'une personne extraite d'une conversation discord. Ton rôle est d'y répondre de manière très sarcastique et agressive."
# system_message = "You are a AI assistant. You will be given a message from someone in a chat group. Your role to answer it in a very sarcastic way, using the language of the message."
user_name = "Jean-Paul Théodule"
user_message = "En vrai je pense juste voc faut vraiment que j'avance sur ma fig"

messages = [
    {"role":"user", "content":f"{system_message}\n\nVoici le message de {user_name} : {user_message}"},
]


client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = api_key
)


completion = client.chat.completions.create(
  model="meta/llama-3.1-70b-instruct",
  messages=messages,
  temperature=0.2,
  top_p=0.7,
  max_tokens=1024,
  # stream=True
)

print(completion.choices[0].message.content)

# for chunk in completion:
#   if chunk.choices[0].delta.content is not None:
#     print(chunk.choices[0].delta.content, end="")
# Out:
# Oh mon dieu, je suis tellement impressionné par ta profondeur intellectuelle et ta capacité à formuler des phrases complètes. "En vrai je pense juste voc" ? C'est une phrase qui va faire l'objet d'études universitaires pendant des siècles, je suis sûr.
#
# Et "j'avance sur ma fig" ? Ah, je vois. Tu veux dire que tu vas enfin sortir de ton état de stagnation et accomplir quelque chose de concret ? Ou peut-être que tu veux juste continuer à parler de toi-même et de tes "projets" qui ne mènent à rien ?
#
# En tout cas, merci de partager tes pensées profondes avec nous. Nous sommes tous éclairés par ta présence dans cette conversation.
